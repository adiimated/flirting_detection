# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_parquet('/content/drive/MyDrive/Colab Notebooks/flirting.parquet')
df.to_csv('/content/drive/MyDrive/Colab Notebooks/flirting.csv')

# %%
df = pd.read_parquet('/content/drive/MyDrive/Colab Notebooks/test.parquet')
df.to_csv('/content/drive/MyDrive/Colab Notebooks/test.csv')

# %%
df = pd.read_parquet('/content/drive/MyDrive/Colab Notebooks/validation.parquet')
df.to_csv('/content/drive/MyDrive/Colab Notebooks/validation.csv')
